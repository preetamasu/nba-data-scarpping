# %%
pip install beautifulsoup4
# Out:
#   Cell In[5], line 1
#     pip install beautifulsoup4
#         ^
# SyntaxError: invalid syntax

# %%
import os
from bs4 import BeautifulSoup
from playwright.sync_api import sync_playwright, TimeoutError as PlaywrightTimeout
import time
from bs4 import BeautifulSoup

# %%
pip install playwright
# Out:
# Collecting playwright
#   Downloading playwright-1.60.0-py3-none-win_amd64.whl.metadata (3.5 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting greenlet<4.0.0,>=3.1.1 (from playwright)
#   Downloading greenlet-3.5.1-cp314-cp314-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions in c:\users\vpree\desktop\nba-predictions\venv\lib\site-packages (from pyee<14,>=13->playwright) (4.15.0)
# Downloading playwright-1.60.0-py3-none-win_amd64.whl (37.9 MB)
#    ---------------------------------------- 0.0/37.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/37.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/37.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/37.9 MB 1.5 MB/s eta 0:00:25
#     --------------------------------------- 0.8/37.9 MB 1.5 MB/s eta 0:00:26
#    - -------------------------------------- 1.3/37.9 MB 1.6 MB/s eta 0:00:23
#    - -------------------------------------- 1.6/37.9 MB 1.6 MB/s eta 0:00:23
#    - -------------------------------------- 1.8/37.9 MB 1.5 MB/s eta 0:00:24
#    -- ------------------------------------- 2.1/37.9 MB 1.5 MB/s eta 0:00:24
#    -- ------------------------------------- 2.4/37.9 MB 1.5 MB/s eta 0:00:24
#    --- ------------------------------------ 2.9/37.9 MB 1.6 MB/s eta 0:00:23
#    --- ------------------------------------ 2.9/37.9 MB 1.6 MB/s eta 0:00:23
#    --- ------------------------------------ 3.1/37.9 MB 1.5 MB/s eta 0:00:24
#    --- ------------------------------------ 3.4/37.9 MB 1.5 MB/s eta 0:00:24
#    --- ------------------------------------ 3.7/37.9 MB 1.4 MB/s eta 0:00:26
#    --- ------------------------------------ 3.7/37.9 MB 1.4 MB/s eta 0:00:26
#    ---- ----------------------------------- 3.9/37.9 MB 1.3 MB/s eta 0:00:27
#    ---- ----------------------------------- 3.9/37.9 MB 1.3 MB/s eta 0:00:27
#    ---- ----------------------------------- 4.5/37.9 MB 1.3 MB/s eta 0:00:27
#    ---- ----------------------------------- 4.7/37.9 MB 1.3 MB/s eta 0:00:27
#    ---- ----------------------------------- 4.7/37.9 MB 1.3 MB/s eta 0:00:27
#    ----- ---------------------------------- 5.0/37.9 MB 1.2 MB/s eta 0:00:28
#    ----- ---------------------------------- 5.0/37.9 MB 1.2 MB/s eta 0:00:28
#    ----- ---------------------------------- 5.2/37.9 MB 1.2 MB/s eta 0:00:28
#    ----- ---------------------------------- 5.5/37.9 MB 1.1 MB/s eta 0:00:29
#    ----- ---------------------------------- 5.5/37.9 MB 1.1 MB/s eta 0:00:29
#    ----- ---------------------------------- 5.5/37.9 MB 1.1 MB/s eta 0:00:29
#    ------ --------------------------------- 5.8/37.9 MB 1.1 MB/s eta 0:00:30
#    ------ --------------------------------- 5.8/37.9 MB 1.1 MB/s eta 0:00:30
#    ------ --------------------------------- 6.3/37.9 MB 1.1 MB/s eta 0:00:30
#    ------ --------------------------------- 6.3/37.9 MB 1.1 MB/s eta 0:00:30
#    ------ --------------------------------- 6.6/37.9 MB 1.1 MB/s eta 0:00:30
#    ------- -------------------------------- 6.8/37.9 MB 1.1 MB/s eta 0:00:30
#    ------- -------------------------------- 7.1/37.9 MB 1.1 MB/s eta 0:00:29
#    ------- -------------------------------- 7.3/37.9 MB 1.1 MB/s eta 0:00:29
#    ------- -------------------------------- 7.3/37.9 MB 1.1 MB/s eta 0:00:29
#    -------- ------------------------------- 7.6/37.9 MB 1.0 MB/s eta 0:00:30
#    -------- ------------------------------- 7.9/37.9 MB 1.0 MB/s eta 0:00:29
#    -------- ------------------------------- 7.9/37.9 MB 1.0 MB/s eta 0:00:29
#    -------- ------------------------------- 7.9/37.9 MB 1.0 MB/s eta 0:00:29
#    -------- ------------------------------- 8.1/37.9 MB 997.8 kB/s eta 0:00:30
#    -------- ------------------------------- 8.4/37.9 MB 995.7 kB/s eta 0:00:30
#    -------- ------------------------------- 8.4/37.9 MB 995.7 kB/s eta 0:00:30
#    --------- ------------------------------ 8.7/37.9 MB 999.3 kB/s eta 0:00:30
#    --------- ------------------------------ 8.9/37.9 MB 1.0 MB/s eta 0:00:29
#    --------- ------------------------------ 9.2/37.9 MB 1.0 MB/s eta 0:00:29
#    --------- ------------------------------ 9.2/37.9 MB 1.0 MB/s eta 0:00:29
#    --------- ------------------------------ 9.4/37.9 MB 997.0 kB/s eta 0:00:29
#    ---------- ----------------------------- 9.7/37.9 MB 988.1 kB/s eta 0:00:29
#    ---------- ----------------------------- 10.0/37.9 MB 991.5 kB/s eta 0:00:29
#    ---------- ----------------------------- 10.0/37.9 MB 991.5 kB/s eta 0:00:29
#    ---------- ----------------------------- 10.2/37.9 MB 983.6 kB/s eta 0:00:29
#    ---------- ----------------------------- 10.2/37.9 MB 983.6 kB/s eta 0:00:29
#    ----------- ---------------------------- 10.5/37.9 MB 976.3 kB/s eta 0:00:29
#    ----------- ---------------------------- 10.7/37.9 MB 979.8 kB/s eta 0:00:28
#    ----------- ---------------------------- 10.7/37.9 MB 979.8 kB/s eta 0:00:28
#    ----------- ---------------------------- 11.3/37.9 MB 979.6 kB/s eta 0:00:28
#    ------------- -------------------------- 12.6/37.9 MB 1.1 MB/s eta 0:00:24
#    -------------- ------------------------- 13.9/37.9 MB 1.2 MB/s eta 0:00:21
#    --------------- ------------------------ 14.7/37.9 MB 1.2 MB/s eta 0:00:20
#    ---------------- ----------------------- 15.5/37.9 MB 1.3 MB/s eta 0:00:18
#    ----------------- ---------------------- 16.3/37.9 MB 1.3 MB/s eta 0:00:17
#    ------------------ --------------------- 17.6/37.9 MB 1.4 MB/s eta 0:00:15
#    ------------------- -------------------- 18.6/37.9 MB 1.4 MB/s eta 0:00:14
#    --------------------- ------------------ 20.4/37.9 MB 1.6 MB/s eta 0:00:12
#    ---------------------- ----------------- 21.5/37.9 MB 1.6 MB/s eta 0:00:11
#    ----------------------- ---------------- 22.5/37.9 MB 1.7 MB/s eta 0:00:10
#    ------------------------- -------------- 24.1/37.9 MB 1.8 MB/s eta 0:00:08
#    --------------------------- ------------ 25.7/37.9 MB 1.8 MB/s eta 0:00:07
#    ----------------------------- ---------- 28.0/37.9 MB 2.0 MB/s eta 0:00:05
#    ------------------------------ --------- 29.4/37.9 MB 2.0 MB/s eta 0:00:05
#    -------------------------------- ------- 30.9/37.9 MB 2.1 MB/s eta 0:00:04
#    ---------------------------------- ----- 32.5/37.9 MB 2.2 MB/s eta 0:00:03
#    ------------------------------------ --- 34.3/37.9 MB 2.3 MB/s eta 0:00:02
#    ------------------------------------- -- 35.1/37.9 MB 2.3 MB/s eta 0:00:02
#    -------------------------------------- - 36.2/37.9 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.9 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  37.7/37.9 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 37.9/37.9 MB 2.4 MB/s  0:00:16
# Downloading greenlet-3.5.1-cp314-cp314-win_amd64.whl (239 kB)
# Downloading pyee-13.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, greenlet, playwright
#
#    ---------------------------------------- 0/3 [pyee]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    ---------------------------------------- 3/3 [playwright]
#
# Successfully installed greenlet-3.5.1 playwright-1.60.0 pyee-13.0.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
SEASONS = list(range(2016,2026))
SEASONS
# Out:
# [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]

# %%
DATA_DIR = "data2"
STANDINGS_DIR = os.path.join(DATA_DIR,"standings")
SCORES_DIR = os.path.join(DATA_DIR,"scores")

# %%
# async def get_html(url,selector,sleep=5,retries=3):
#     html = None
#     for i in range(1,retries+1):
#         time.sleep(sleep * i) 
#         try:
#             async with async_playwright() as p:
#                 browser = await p.chromium.launch()
#                 page = await browser.new_page()
#                 await page.goto(url)
#                 print(await page.title())
#                 html = await page.inner_html(selector)
#         except PlaywrightTimeout:
#             print(f"Timeout has been there for this {url}")
#             continue
#         else:
#             break
#     return html

# %%
season = 2016
url = f"https://www.basketball-reference.com/leagues/NBA_{season}_games.html"
url
# Out:
# 'https://www.basketball-reference.com/leagues/NBA_2016_games.html'

# %%
# Out:
# ---------------------
# ErrorTraceback (most recent call last)
# Cell In[16], line 1
# ----> 1 html = await get_html(url,"#content .filter")
#
# Cell In[15], line 14, in get_html(url, selector, sleep, retries)
#      10                 page.goto(url)
#      11                 print(page.title())
#      12                 html = page.inner_html(selector)
#      13                 browser.close()
# ---> 14         except PlaywrightTimeout:
#      15             print(f"Timeout happened for {url}")
#      16             continue
#      17         else:
#
# File ~\Desktop\NBA-Predictions\venv\Lib\site-packages\playwright\sync_api\_context_manager.py:47, in PlaywrightContextManager.__enter__(self)
#      45             self._own_loop = True
#      46         if self._loop.is_running():
# ---> 47             raise Error(
#      48                 """It looks like you are using Playwright Sync API inside the asyncio loop.
#      49 Please use the Async API instead."""
#      50             )
#      52         # Create a new fiber for the protocol dispatcher. It will be pumping events
#      53         # until the end of times. We will pass control to that fiber every time we
#      54         # block while waiting for a response.
#      55         def greenlet_main() -> None:
#
# Error: It looks like you are using Playwright Sync API inside the asyncio loop.
# Please use the Async API instead.

# %%
import asyncio
from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeout

async def get_html(url, selector, sleep=5, retries=3):
    html = None

    for i in range(1, retries + 1):
        await asyncio.sleep(sleep * i)

        try:
            async with async_playwright() as p:
                browser = await p.chromium.launch(headless=True)
                page = await browser.new_page()
                await page.goto(url, timeout=30000)
                print(await page.title())
                html = await page.inner_html(selector)
                await browser.close()
                break

        except PlaywrightTimeout:
            print(f"Timeout happened for {url}")
            continue

    return html

# %%
html = await get_html(url,"#content .filter")
# Out:
# ---------------------
# NotImplementedErrorTraceback (most recent call last)
# Cell In[18], line 1
# ----> 1 html = await get_html(url,"#content .filter")
#
# Cell In[17], line 20, in get_html(url, selector, sleep, retries)
#      16                 html = await page.inner_html(selector)
#      17                 await browser.close()
#      18                 break
#      19
# ---> 20         except PlaywrightTimeout:
#      21             print(f"Timeout happened for {url}")
#      22             continue
#      23
#
# File ~\Desktop\NBA-Predictions\venv\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File ~\Desktop\NBA-Predictions\venv\Lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File C:\Python314\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File C:\Python314\Lib\asyncio\base_events.py:1798, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1796     debug_log = f'execute program {program!r}'
#    1797     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1798 transport = await self._make_subprocess_transport(
#    1799     protocol, popen_args, False, stdin, stdout, stderr,
#    1800     bufsize, **kwargs)
#    1801 if self._debug and debug_log is not None:
#    1802     logger.info('%s: %r', debug_log, transport)
#
# File C:\Python314\Lib\asyncio\base_events.py:533, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     529 async def _make_subprocess_transport(self, protocol, args, shell,
#     530                                      stdin, stdout, stderr, bufsize,
#     531                                      extra=None, **kwargs):
#     532     """Create subprocess transport."""
# --> 533     raise NotImplementedError
#
# NotImplementedError:

# %%
standing_files = os.listdir(STANDINGS_DIR)

# %%
standing_files
# Out:
# ['.ipynb_checkpoints',
#  'NBA_2016_games-april.html',
#  'NBA_2016_games-december.html',
#  'NBA_2016_games-february.html',
#  'NBA_2016_games-january.html',
#  'NBA_2016_games-june.html',
#  'NBA_2016_games-march.html',
#  'NBA_2016_games-may.html',
#  'NBA_2016_games-november.html',
#  'NBA_2016_games-october.html',
#  'NBA_2017_games-april.html',
#  'NBA_2017_games-december.html',
#  'NBA_2017_games-february.html',
#  'NBA_2017_games-january.html',
#  'NBA_2017_games-june.html',
#  'NBA_2017_games-march.html',
#  'NBA_2017_games-may.html',
#  'NBA_2017_games-november.html',
#  'NBA_2017_games-october.html',
#  'NBA_2018_games-april.html',
#  'NBA_2018_games-december.html',
#  'NBA_2018_games-february.html',
#  'NBA_2018_games-january.html',
#  'NBA_2018_games-june.html',
#  'NBA_2018_games-march.html',
#  'NBA_2018_games-may.html',
#  'NBA_2018_games-november.html',
#  'NBA_2018_games-october.html',
#  'NBA_2019_games-april.html',
#  'NBA_2019_games-december.html',
#  'NBA_2019_games-february.html',
#  'NBA_2019_games-january.html',
#  'NBA_2019_games-june.html',
#  'NBA_2019_games-march.html',
#  'NBA_2019_games-may.html',
#  'NBA_2019_games-november.html',
#  'NBA_2019_games-october.html',
#  'NBA_2020_games-august.html',
#  'NBA_2020_games-december.html',
#  'NBA_2020_games-february.html',
#  'NBA_2020_games-january.html',
#  'NBA_2020_games-july.html',
#  'NBA_2020_games-march.html',
#  'NBA_2020_games-november.html',
#  'NBA_2020_games-october-2019.html',
#  'NBA_2020_games-october-2020.html',
#  'NBA_2020_games-september.html',
#  'NBA_2021_games-april.html',
#  'NBA_2021_games-december.html',
#  'NBA_2021_games-february.html',
#  'NBA_2021_games-january.html',
#  'NBA_2021_games-july.html',
#  'NBA_2021_games-june.html',
#  'NBA_2021_games-march.html',
#  'NBA_2021_games-may.html']

# %%
standings_file = os.path.join(STANDINGS_DIR,standing_files[1])
standings_file
# Out:
# 'data2\\standings\\NBA_2016_games-april.html'

# %%
with open(standings_file,'r') as f:
    html = f.read()
soup = BeautifulSoup(html)
links = soup.find_all("a")
links
hrefs = [l.get("href") for l in links]
boxscores = [l for l in hrefs if l and "boxscore" in l and ".html" in l]
boxscores_f = [f"http://basketball-reference.com{l}" for l in boxscores]
boxscores_f
# Out:
# ['http://basketball-reference.com/boxscores/201604010CHO.html',
#  'http://basketball-reference.com/boxscores/201604010DET.html',
#  'http://basketball-reference.com/boxscores/201604010NYK.html',
#  'http://basketball-reference.com/boxscores/201604010ATL.html',
#  'http://basketball-reference.com/boxscores/201604010MEM.html',
#  'http://basketball-reference.com/boxscores/201604010MIL.html',
#  'http://basketball-reference.com/boxscores/201604010UTA.html',
#  'http://basketball-reference.com/boxscores/201604010SAC.html',
#  'http://basketball-reference.com/boxscores/201604010GSW.html',
#  'http://basketball-reference.com/boxscores/201604010PHO.html',
#  'http://basketball-reference.com/boxscores/201604020PHI.html',
#  'http://basketball-reference.com/boxscores/201604020CHI.html',
#  'http://basketball-reference.com/boxscores/201604020SAS.html',
#  'http://basketball-reference.com/boxscores/201604020DEN.html',
#  'http://basketball-reference.com/boxscores/201604020POR.html',
#  'http://basketball-reference.com/boxscores/201604030BRK.html',
#  'http://basketball-reference.com/boxscores/201604030CLE.html',
#  'http://basketball-reference.com/boxscores/201604030HOU.html',
#  'http://basketball-reference.com/boxscores/201604030LAC.html',
#  'http://basketball-reference.com/boxscores/201604030MIN.html',
#  'http://basketball-reference.com/boxscores/201604030ORL.html',
#  'http://basketball-reference.com/boxscores/201604030PHO.html',
#  'http://basketball-reference.com/boxscores/201604030MIL.html',
#  'http://basketball-reference.com/boxscores/201604030NYK.html',
#  'http://basketball-reference.com/boxscores/201604030GSW.html',
#  'http://basketball-reference.com/boxscores/201604030LAL.html',
#  'http://basketball-reference.com/boxscores/201604050PHI.html',
#  'http://basketball-reference.com/boxscores/201604050TOR.html',
#  'http://basketball-reference.com/boxscores/201604050ATL.html',
#  'http://basketball-reference.com/boxscores/201604050MEM.html',
#  'http://basketball-reference.com/boxscores/201604050MIA.html',
#  'http://basketball-reference.com/boxscores/201604050MIL.html',
#  'http://basketball-reference.com/boxscores/201604050DEN.html',
#  'http://basketball-reference.com/boxscores/201604050UTA.html',
#  'http://basketball-reference.com/boxscores/201604050SAC.html',
#  'http://basketball-reference.com/boxscores/201604050GSW.html',
#  'http://basketball-reference.com/boxscores/201604050LAC.html',
#  'http://basketball-reference.com/boxscores/201604060IND.html',
#  'http://basketball-reference.com/boxscores/201604060ORL.html',
#  'http://basketball-reference.com/boxscores/201604060WAS.html',
#  'http://basketball-reference.com/boxscores/201604060BOS.html',
#  'http://basketball-reference.com/boxscores/201604060NYK.html',
#  'http://basketball-reference.com/boxscores/201604060DAL.html',
#  'http://basketball-reference.com/boxscores/201604060POR.html',
#  'http://basketball-reference.com/boxscores/201604060LAL.html',
#  'http://basketball-reference.com/boxscores/201604070ATL.html',
#  'http://basketball-reference.com/boxscores/201604070HOU.html',
#  'http://basketball-reference.com/boxscores/201604070MIA.html',
#  'http://basketball-reference.com/boxscores/201604070SAC.html',
#  'http://basketball-reference.com/boxscores/201604070GSW.html',
#  'http://basketball-reference.com/boxscores/201604080CHO.html',
#  'http://basketball-reference.com/boxscores/201604080ORL.html',
#  'http://basketball-reference.com/boxscores/201604080PHI.html',
#  'http://basketball-reference.com/boxscores/201604080BOS.html',
#  'http://basketball-reference.com/boxscores/201604080DET.html',
#  'http://basketball-reference.com/boxscores/201604080TOR.html',
#  'http://basketball-reference.com/boxscores/201604080NOP.html',
#  'http://basketball-reference.com/boxscores/201604080DAL.html',
#  'http://basketball-reference.com/boxscores/201604080DEN.html',
#  'http://basketball-reference.com/boxscores/201604080UTA.html',
#  'http://basketball-reference.com/boxscores/201604090NOP.html',
#  'http://basketball-reference.com/boxscores/201604090ATL.html',
#  'http://basketball-reference.com/boxscores/201604090MEM.html',
#  'http://basketball-reference.com/boxscores/201604090CHI.html',
#  'http://basketball-reference.com/boxscores/201604090POR.html',
#  'http://basketball-reference.com/boxscores/201604090SAC.html',
#  'http://basketball-reference.com/boxscores/201604100WAS.html',
#  'http://basketball-reference.com/boxscores/201604100HOU.html',
#  'http://basketball-reference.com/boxscores/201604100LAC.html',
#  'http://basketball-reference.com/boxscores/201604100DEN.html',
#  'http://basketball-reference.com/boxscores/201604100PHI.html',
#  'http://basketball-reference.com/boxscores/201604100IND.html',
#  'http://basketball-reference.com/boxscores/201604100MIA.html',
#  'http://basketball-reference.com/boxscores/201604100SAS.html',
#  'http://basketball-reference.com/boxscores/201604100NYK.html',
#  'http://basketball-reference.com/boxscores/201604110CLE.html',
#  'http://basketball-reference.com/boxscores/201604110ORL.html',
#  'http://basketball-reference.com/boxscores/201604110BOS.html',
#  'http://basketball-reference.com/boxscores/201604110BRK.html',
#  'http://basketball-reference.com/boxscores/201604110MIN.html',
#  'http://basketball-reference.com/boxscores/201604110NOP.html',
#  'http://basketball-reference.com/boxscores/201604110OKC.html',
#  'http://basketball-reference.com/boxscores/201604110UTA.html',
#  'http://basketball-reference.com/boxscores/201604110PHO.html',
#  'http://basketball-reference.com/boxscores/201604120IND.html',
#  'http://basketball-reference.com/boxscores/201604120DET.html',
#  'http://basketball-reference.com/boxscores/201604120TOR.html',
#  'http://basketball-reference.com/boxscores/201604120SAS.html',
#  'http://basketball-reference.com/boxscores/201604120LAC.html',
#  'http://basketball-reference.com/boxscores/201604130BOS.html',
#  'http://basketball-reference.com/boxscores/201604130BRK.html',
#  'http://basketball-reference.com/boxscores/201604130CHI.html',
#  'http://basketball-reference.com/boxscores/201604130CHO.html',
#  'http://basketball-reference.com/boxscores/201604130CLE.html',
#  'http://basketball-reference.com/boxscores/201604130DAL.html',
#  'http://basketball-reference.com/boxscores/201604130HOU.html',
#  'http://basketball-reference.com/boxscores/201604130MIL.html',
#  'http://basketball-reference.com/boxscores/201604130MIN.html',
#  'http://basketball-reference.com/boxscores/201604130WAS.html',
#  'http://basketball-reference.com/boxscores/201604130GSW.html',
#  'http://basketball-reference.com/boxscores/201604130LAL.html',
#  'http://basketball-reference.com/boxscores/201604130PHO.html',
#  'http://basketball-reference.com/boxscores/201604130POR.html',
#  'http://basketball-reference.com/boxscores/201604160TOR.html',
#  'http://basketball-reference.com/boxscores/201604160GSW.html',
#  'http://basketball-reference.com/boxscores/201604160ATL.html',
#  'http://basketball-reference.com/boxscores/201604160OKC.html',
#  'http://basketball-reference.com/boxscores/201604170CLE.html',
#  'http://basketball-reference.com/boxscores/201604170MIA.html',
#  'http://basketball-reference.com/boxscores/201604170SAS.html',
#  'http://basketball-reference.com/boxscores/201604170LAC.html',
#  'http://basketball-reference.com/boxscores/201604180TOR.html',
#  'http://basketball-reference.com/boxscores/201604180OKC.html',
#  'http://basketball-reference.com/boxscores/201604180GSW.html',
#  'http://basketball-reference.com/boxscores/201604190ATL.html',
#  'http://basketball-reference.com/boxscores/201604190SAS.html',
#  'http://basketball-reference.com/boxscores/201604200MIA.html',
#  'http://basketball-reference.com/boxscores/201604200CLE.html',
#  'http://basketball-reference.com/boxscores/201604200LAC.html',
#  'http://basketball-reference.com/boxscores/201604210DAL.html',
#  'http://basketball-reference.com/boxscores/201604210IND.html',
#  'http://basketball-reference.com/boxscores/201604210HOU.html',
#  'http://basketball-reference.com/boxscores/201604220DET.html',
#  'http://basketball-reference.com/boxscores/201604220BOS.html',
#  'http://basketball-reference.com/boxscores/201604220MEM.html',
#  'http://basketball-reference.com/boxscores/201604230IND.html',
#  'http://basketball-reference.com/boxscores/201604230CHO.html',
#  'http://basketball-reference.com/boxscores/201604230DAL.html',
#  'http://basketball-reference.com/boxscores/201604230POR.html',
#  'http://basketball-reference.com/boxscores/201604240MEM.html',
#  'http://basketball-reference.com/boxscores/201604240HOU.html',
#  'http://basketball-reference.com/boxscores/201604240BOS.html',
#  'http://basketball-reference.com/boxscores/201604240DET.html',
#  'http://basketball-reference.com/boxscores/201604250CHO.html',
#  'http://basketball-reference.com/boxscores/201604250OKC.html',
#  'http://basketball-reference.com/boxscores/201604250POR.html',
#  'http://basketball-reference.com/boxscores/201604260TOR.html',
#  'http://basketball-reference.com/boxscores/201604260ATL.html',
#  'http://basketball-reference.com/boxscores/201604270MIA.html',
#  'http://basketball-reference.com/boxscores/201604270LAC.html',
#  'http://basketball-reference.com/boxscores/201604270GSW.html',
#  'http://basketball-reference.com/boxscores/201604280BOS.html',
#  'http://basketball-reference.com/boxscores/201604290IND.html',
#  'http://basketball-reference.com/boxscores/201604290CHO.html',
#  'http://basketball-reference.com/boxscores/201604290POR.html',
#  'http://basketball-reference.com/boxscores/201604300SAS.html']
